# %% [markdown]
# **Ques1.** Write a function to compute 5/0 and use try/except to catch the exceptions.

# %%
try:
    a = 5
    b = 0
    print(a/b)
except Exception as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# **Ques2.** Implement a Python program to generate all sentences where subject is in ["Americans", "Indians"] and verb is in ["Play", "watch"] and the object is in ["Baseball","cricket"].

# %%
subjects = ["Americans", "Indians"]
verbs = ["play", "watch"]
objects = ["Baseball", "Cricket"]

# %%
for i in subjects:
    for j in verbs:
        for k in objects:
            print(i+" "+j+" "+k)
# Out:
# Americans play Baseball
# Americans play Cricket
# Americans watch Baseball
# Americans watch Cricket
# Indians play Baseball
# Indians play Cricket
# Indians watch Baseball
# Indians watch Cricket
